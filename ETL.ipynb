# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
indicadores = [
    "NY.GNP.PCAP.CD",  # PIB per cápita
    "SP.DYN.LE00.IN",  # Esperanza de vida al nacer
    "SH.DYN.MORT",  # Mortalidad infantil
    "SE.ADT.LITR.ZS",  # Tasa de alfabetización
    "SE.XPD.TOTL.GD.ZS",  # Gasto en educación
    "SH.H2O.SAFE.ZS",  # Acceso a agua potable
    "SH.MED.BEDS.ZS",  # Acceso a servicios de salud
    "SL.UEM.TOTL.ZS",  # Desempleo
    "HDI",  # Índice de desarrollo humano (IDH)
    "SP.DYN.TFRT.IN"  # Tasa de fecundidad
]

data = pd.read_csv('WDIData.csv')
indicadores_df = data.loc[data['Indicator Code'].isin(indicadores)]

# %%
data.head(10)
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
# 5  Africa Eastern and Southern          AFE
# 6  Africa Eastern and Southern          AFE
# 7  Africa Eastern and Southern          AFE
# 8  Africa Eastern and Southern          AFE
# 9  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS   NaN
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
# 5  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS   NaN
# 6  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS   NaN
# 7  Account ownership at a financial institution o...  FX.OWN.TOTL.FE.ZS   NaN
# 8  Account ownership at a financial institution o...  FX.OWN.TOTL.MA.ZS   NaN
# 9  Account ownership at a financial institution o...  FX.OWN.TOTL.OL.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2014       2015       2016  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  17.196986  17.597176  18.034249
# 1   NaN   NaN   NaN   NaN   NaN  ...   6.580066   6.786218   6.941323
# 2   NaN   NaN   NaN   NaN   NaN  ...  37.857526  38.204173  38.303515
# 3   NaN   NaN   NaN   NaN   NaN  ...  31.824950  33.744405  38.733352
# 4   NaN   NaN   NaN   NaN   NaN  ...  17.485006  16.329765  24.372504
# 5   NaN   NaN   NaN   NaN   NaN  ...  66.146834  66.936479  68.977838
# 6   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 7   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 8   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 9   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
#
#         2017       2018       2019       2020  2021  2022  Unnamed: 67
# 0  18.345878  18.695306  19.149942  19.501837   NaN   NaN          NaN
# 1   7.096843   7.254828   7.460783   7.599289   NaN   NaN          NaN
# 2  38.421813  38.482409  38.692053  38.793983   NaN   NaN          NaN
# 3  40.092163  42.880977  44.073912  45.609604   NaN   NaN          NaN
# 4  25.153292  27.227391  29.383000  30.163364   NaN   NaN          NaN
# 5  70.771730  71.692427  73.164863  73.775675   NaN   NaN          NaN
# 6        NaN        NaN        NaN        NaN   NaN   NaN          NaN
# 7        NaN        NaN        NaN        NaN   NaN   NaN          NaN
# 8        NaN        NaN        NaN        NaN   NaN   NaN          NaN
# 9        NaN        NaN        NaN        NaN   NaN   NaN          NaN
#
# [10 rows x 68 columns]

# %%
# Lista de países de América Latina
paises_latinoamerica = ['Antigua and Barbuda', 'Argentina', 'Bolivia', 'Brazil', 'Belize', 'Bahamas, The', 'Barbados', 'Chile', 'Colombia', 'Costa Rica', 'Cuba', 
 'Dominican Republic', 'Dominica', 'Ecuador', 'El Salvador', 'Grenada', 'Guatemala', 'Guyana', 'Haiti', 'Honduras', 'Jamaica', 'Nicaragua', 'Panama', 'Paraguay',  
 'Peru', 'Puerto Rico', 'Suriname', 'St. Kitts and Nevis', 'St. Lucia', 'St. Vincent and the Grenadines', 'Trinidad and Tobago','Uruguay', 'Venezuela, RB',]

indicadores_latinoamerica = indicadores_df.loc[indicadores_df['Country Name'].isin(paises_latinoamerica)]
indicadores_latinoamerica.to_csv('indicadores_latinoamerica.csv')

# %%
indicadores_latinoamerica.reset_index(inplace=True)
indicadores_latinoamerica.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 69 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   index           264 non-null    int64
#  1   Country Name    264 non-null    object
#  2   Country Code    264 non-null    object
#  3   Indicator Name  264 non-null    object
#  4   Indicator Code  264 non-null    object
#  5   1960            124 non-null    float64
#  6   1961            93 non-null     float64
#  7   1962            112 non-null    float64
#  8   1963            112 non-null    float64
#  9   1964            113 non-null    float64
#  10  1965            113 non-null    float64
#  11  1966            114 non-null    float64
#  12  1967            116 non-null    float64
#  13  1968            118 non-null    float64
#  14  1969            119 non-null    float64
#  15  1970            162 non-null    float64
#  16  1971            127 non-null    float64
#  17  1972            125 non-null    float64
#  18  1973            126 non-null    float64
#  19  1974            128 non-null    float64
#  20  1975            146 non-null    float64
#  21  1976            130 non-null    float64
#  22  1977            130 non-null    float64
#  23  1978            127 non-null    float64
#  24  1979            134 non-null    float64
#  25  1980            158 non-null    float64
#  26  1981            136 non-null    float64
#  27  1982            142 non-null    float64
#  28  1983            138 non-null    float64
#  29  1984            144 non-null    float64
#  30  1985            150 non-null    float64
#  31  1986            142 non-null    float64
#  32  1987            138 non-null    float64
#  33  1988            134 non-null    float64
#  34  1989            144 non-null    float64
#  35  1990            172 non-null    float64
#  36  1991            170 non-null    float64
#  37  1992            170 non-null    float64
#  38  1993            196 non-null    float64
#  39  1994            177 non-null    float64
#  40  1995            185 non-null    float64
#  41  1996            205 non-null    float64
#  42  1997            165 non-null    float64
#  43  1998            177 non-null    float64
#  44  1999            182 non-null    float64
#  45  2000            199 non-null    float64
#  46  2001            198 non-null    float64
#  47  2002            200 non-null    float64
#  48  2003            205 non-null    float64
#  49  2004            198 non-null    float64
#  50  2005            201 non-null    float64
#  51  2006            201 non-null    float64
#  52  2007            217 non-null    float64
#  53  2008            206 non-null    float64
#  54  2009            215 non-null    float64
#  55  2010            221 non-null    float64
#  56  2011            218 non-null    float64
#  57  2012            220 non-null    float64
#  58  2013            220 non-null    float64
#  59  2014            228 non-null    float64
#  60  2015            233 non-null    float64
#  61  2016            227 non-null    float64
#  62  2017            223 non-null    float64
#  63  2018            206 non-null    float64
#  64  2019            195 non-null    float64
#  65  2020            191 non-null    float64
#  66  2021            180 non-null    float64
#  67  2022            29 non-null     float64
#  68  Unnamed: 67     0 non-null      float64
# dtypes: float64(64), int64(1), object(4)
# memory usage: 142.4+ KB

# %%
porcentaje_nulos = indicadores_latinoamerica.isnull().mean(axis=1) * 100
filas_con_nulos = porcentaje_nulos[porcentaje_nulos >= 20].index
print(filas_con_nulos)
# Out:
# Int64Index([  1,   2,   3,   5,   7,  10,  11,  13,  15,  18,
#             ...
#             245, 247, 250, 251, 253, 255, 258, 259, 261, 263],
#            dtype='int64', length=144)

# %%
indicadores_latinoamerica = indicadores_latinoamerica.drop(filas_con_nulos)

# %%
columnas_float = ['1960', '1961', '1962', '1963', '1964', '1965',
       '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974',
       '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
       '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
       '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
       '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
       '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
       '2020', '2021', '2022']

indicadores_latinoamerica[columnas_float] = indicadores_latinoamerica[columnas_float].astype('float')

# Aplicar interpolación por fila
indicadores_latinoamerica[columnas_float] = indicadores_latinoamerica[columnas_float].interpolate(axis=1)

# %%
indicadores_latinoamerica.head()
# Out:
#    index         Country Name Country Code  \
# 0  81716  Antigua and Barbuda          ATG
# 4  81999  Antigua and Barbuda          ATG
# 6  82098  Antigua and Barbuda          ATG
# 8  83194            Argentina          ARG
# 9  83275            Argentina          ARG
#
#                                     Indicator Name  Indicator Code    1960  \
# 0         Fertility rate, total (births per woman)  SP.DYN.TFRT.IN   4.602
# 4          Life expectancy at birth, total (years)  SP.DYN.LE00.IN  61.550
# 6  Mortality rate, under-5 (per 1,000 live births)     SH.DYN.MORT  86.300
# 8         Fertility rate, total (births per woman)  SP.DYN.TFRT.IN   3.075
# 9       GNI per capita, Atlas method (current US$)  NY.GNP.PCAP.CD     NaN
#
#      1961    1962    1963      1964  ...       2014       2015       2016  \
# 0   4.559   4.547   4.536     4.484  ...      1.526      1.567      1.458
# 4  62.363  63.192  64.101    65.058  ...     77.858     77.913     78.152
# 6  80.400  74.000  67.400    60.800  ...      8.100      7.700      7.400
# 8   3.069   3.106   3.101     3.080  ...      2.312      2.301      2.241
# 9     NaN     NaN     NaN  1130.000  ...  12350.000  12600.000  12220.000
#
#         2017       2018       2019      2020      2021      2022  Unnamed: 67
# 0      1.485      1.371      1.468     1.569     1.580     1.580          NaN
# 4     78.268     78.511     78.691    78.841    78.497    78.497          NaN
# 6      7.100      6.800      6.600     6.400     6.100     6.100          NaN
# 8      2.168      2.039      1.994     1.911     1.885     1.885          NaN
# 9  13140.000  12430.000  11220.000  9010.000  9960.000  9960.000          NaN
#
# [5 rows x 69 columns]

# %%
indicadores_latinoamerica = indicadores_latinoamerica.loc[:, ~indicadores_latinoamerica.columns.str.contains('^Unnamed')]

indicadores_latinoamerica.to_csv('indicadores_latinoamerica.csv')
